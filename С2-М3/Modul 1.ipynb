# %% [markdown]
# #  Загрузка и подготовка данных

# %%
#Загрузка необходимых библиотек
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
# Загрузка данных, удаление лишних данных по всем 3 выборкам
try:
    df1=pd.read_csv('SOP1.dat',delimiter=' ',encoding='windows-1250',header=None,error_bad_lines=False)
    
    df2=pd.read_csv('SOP2.dat',delimiter=' ',encoding='windows-1250',header=None,error_bad_lines=False)
    df3=pd.read_csv('SOP3.dat',delimiter=' ',encoding='windows-1250',header=None,error_bad_lines=False)
except:
    print('Данные не загрузились ')
    
try:  
    df1=df1.drop([0,0]) # удаление технической строки
    df1=df1.drop(columns=[17,0]) # удаление лишних столбцов,   расстояние мм будет индекс
    df2=df2.drop([0,0]) # удаление технической строки
    df2=df2.drop(columns=[17,0])  # удаление лишних столбцов,   расстояние мм будет индекс 
    df3=df3.drop([0,0]) # удаление технической строки
    df3=df3.drop(columns=[17,0])# удаление лишних столбцов,   расстояние мм будет индекс
    df1=df1.astype("float32")# приводим данные к инт
    df2=df2.astype("float32")# приводим данные к инт
    df3=df3.astype("float32")# приводим данные к инт
except:
    print('Данные не обработались ')
    
print('Данные загруженны и обработаны ')
# Out:
# Данные загруженны и обработаны

# %%
df3.describe()
# Out:
#                 1            2            3            4            5   \
# count  1038.000000  1038.000000  1038.000000  1038.000000  1038.000000
# mean      0.780347    19.334297    20.899807    16.554913   150.868011
# std       4.388105    49.438477    54.557178    40.423485    85.022842
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000    80.000000
# 50%       0.000000     0.000000     0.000000     0.000000   157.000000
# 75%       0.000000     2.750000     5.000000     8.000000   238.000000
# max      43.000000   255.000000   255.000000   239.000000   255.000000
#
#                 6            7            8            9            10  \
# count  1038.000000  1038.000000  1038.000000  1038.000000  1038.000000
# mean     80.681114     1.052987     1.202312    49.246628    91.547203
# std      61.259487     5.751197     9.125796    69.988640    80.183174
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      29.000000     0.000000     0.000000     3.000000    37.000000
# 50%      75.000000     0.000000     0.000000    20.000000    61.000000
# 75%     118.000000     0.000000     0.000000    57.000000   115.750000
# max     255.000000    64.000000   123.000000   255.000000   255.000000
#
#                 11           12           13           14           15  \
# count  1038.000000  1038.000000  1038.000000  1038.000000  1038.000000
# mean      6.563584    55.935452    72.386322   144.998077    16.466282
# std      19.521847    75.588486    58.833057    85.404861    21.952002
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000    10.000000    22.250000    78.250000     0.000000
# 50%       0.000000    27.000000    64.000000   150.000000     9.000000
# 75%       0.000000    58.000000   111.000000   227.000000    24.000000
# max     135.000000   255.000000   244.000000   255.000000   163.000000
#
#                 16
# count  1038.000000
# mean     15.102119
# std      25.392410
# min       0.000000
# 25%       0.000000
# 50%       8.000000
# 75%      22.750000
# max     255.000000

# %% [markdown]
# ## анализ данных

# %%
# смотрим данные на примере 1 выборки
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1042 entries, 1 to 1042
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1       1042 non-null   float32
#  1   2       1042 non-null   float32
#  2   3       1042 non-null   float32
#  3   4       1042 non-null   float32
#  4   5       1042 non-null   float32
#  5   6       1042 non-null   float32
#  6   7       1042 non-null   float32
#  7   8       1042 non-null   float32
#  8   9       1042 non-null   float32
#  9   10      1042 non-null   float32
#  10  11      1042 non-null   float32
#  11  12      1042 non-null   float32
#  12  13      1042 non-null   float32
#  13  14      1042 non-null   float32
#  14  15      1042 non-null   float32
#  15  16      1042 non-null   float32
# dtypes: float32(16)
# memory usage: 73.3 KB

# %%
# анализ структуры 1 выборки
df1.describe()
# Out:
#                 1            2            3            4            5   \
# count  1042.000000  1042.000000  1042.000000  1042.000000  1042.000000
# mean      0.562380     5.808062    35.482727    16.244722    95.277351
# std       3.775705    19.614969    57.418011    49.011639    64.650665
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000    43.000000
# 50%       0.000000     0.000000    10.000000     0.000000    91.000000
# 75%       0.000000     0.000000    42.000000     0.000000   139.000000
# max      48.000000   141.000000   255.000000   255.000000   255.000000
#
#                 6            7            8            9            10  \
# count  1042.000000  1042.000000  1042.000000  1042.000000  1042.000000
# mean    117.201538     0.488484     1.129559    90.076775    63.525913
# std      86.584702     3.553943     7.236336    74.079521    73.302711
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      35.000000     0.000000     0.000000    37.000000    16.000000
# 50%     113.000000     0.000000     0.000000    65.000000    36.000000
# 75%     195.000000     0.000000     0.000000   118.000000    74.750000
# max     255.000000    63.000000    72.000000   255.000000   255.000000
#
#                 11           12           13           14           15  \
# count  1042.000000  1042.000000  1042.000000  1042.000000  1042.000000
# mean      5.941459    28.148752    65.117081    69.410751     5.101727
# std      18.592899    48.783566    61.193272    74.010910    11.933502
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     7.000000     0.000000     0.000000
# 50%       0.000000     8.000000    55.000000    49.500000     0.000000
# 75%       0.000000    33.000000   103.000000   114.750000     4.000000
# max     145.000000   255.000000   255.000000   255.000000    66.000000
#
#                 16
# count  1042.000000
# mean     17.384836
# std      23.067638
# min       0.000000
# 25%       0.000000
# 50%      10.000000
# 75%      26.000000
# max     189.000000

# %%
# анализ структуры 2 выборки
df2.describe()

# %%
# анализ структуры 3 выборки
df3.describe()

# %% [markdown]
# ## Построение графиков

# %%
# построение гистограмм распределения
type(df1.hist(figsize=(20,10)))
# Out:
# numpy.ndarray

# %%
# Построим ящик с усами для определения плотности в данных. Подставляем датафрейм соответствующий
df1.boxplot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
# Построим график значений в координатах  для каждого признака. Подставляем датафрейм соответствующий
axes = df1.plot.line(subplots=True,figsize=(20,10))
type(axes)
# Out:
# numpy.ndarray

# %%
# Построим график значений в координатах  для каждого признака с усреднением. Подставляем датафрейм соответствующий
axes = df1.rolling(20).mean().plot.line(subplots=True,figsize=(20,10))
type(axes)
# Out:
# numpy.ndarray

# %% [markdown]
# Признаки эхо-метода. Эхо-метод: 1,2,3,4,7,8
# Эхо-контактные :9,10,11,12,15,16
# Признаки теневого метода: 5,6,13,14
# Поперечные дефекты 7,8 эхо контактные 15,16

# %%
(df1.loc[:,1])

# %%
df1[[1,2,3,4,5]]

# %%
sns.pairplot(df1,kind="kde")
plt.show()

# %% [markdown]
# # Построение корреляционных данных и их визуализация

# %%
corr1 = df1[list(df1.columns)].corr()
#corr1=df1.corr(method='pearson', min_periods=1)
corr2=df2.corr(method='pearson', min_periods=1)
corr3=df3.corr(method='pearson', min_periods=1)

# %%
corr1

# %%
sns.clustermap(corr1)

# %%
sns.heatmap(corr1,annot=True)

# %%
sns.heatmap(corr2,annot=True)

# %%
sns.heatmap(corr3,annot=True)
